# %%
from scipy.stats import multivariate_normal
from pandas import read_csv

# %% [markdown]
# ## Config Vars

# %%
codataset = 'data/full_dataset.csv'

# %% [markdown]
# ## Load Dataset

# %%
dataset = read_csv(, header=0, index_col=0)
dataset.head()
# Out:
#             @timestamp  system.cpu.idle.pct  system.cpu.iowait.pct  \
# 0  2018-05-01 00:00:00               3.5818                 0.0474
# 1  2018-05-01 00:00:10               3.5080                 0.0934
# 2  2018-05-01 00:00:20               3.5337                 0.1136
# 3  2018-05-01 00:00:30               3.5742                 0.0503
# 4  2018-05-01 00:00:40               3.5454                 0.0705
#
#    system.cpu.softirq.pct  system.cpu.system.pct  system.cpu.total.pct  \
# 0                  0.0312                 0.1058                0.4182
# 1                  0.0271                 0.1054                0.4920
# 2                  0.0291                 0.1025                0.4663
# 3                  0.0201                 0.0916                0.4258
# 4                  0.0268                 0.1051                0.4546
#
#    system.cpu.user.pct  system.diskio_sda.iostat.await  \
# 0               0.2338                           0.698
# ...

# %%
dataset.columns
# Out:
# Index(['@timestamp', 'system.cpu.idle.pct', 'system.cpu.iowait.pct',
#        'system.cpu.softirq.pct', 'system.cpu.system.pct',
#        'system.cpu.total.pct', 'system.cpu.user.pct',
#        'system.diskio_sda.iostat.await', 'system.diskio_sda.iostat.busy',
#        'system.diskio_sda.iostat.queue.avg_size',
#        'system.diskio_sda.iostat.read.request.merges_per_sec',
#        'system.diskio_sda.iostat.read.request.per_sec',
#        'system.diskio_sda.iostat.request.avg_size',
#        'system.diskio_sda.iostat.service_time',
#        'system.diskio_sda.iostat.write.request.merges_per_sec',
#        'system.diskio_sda.iostat.write.request.per_sec',
#        'system.diskio_sda2.iostat.await', 'system.diskio_sda2.iostat.busy',
#        'system.diskio_sda2.iostat.queue.avg_size',
#        'system.diskio_sda2.iostat.read.request.merges_per_sec',
#        'system.diskio_sda2.iostat.read.request.per_sec',
#        'system.diskio_sda2.iostat.request.avg_size',
# ...
